# %% [markdown]
# <a href="https://colab.research.google.com/github/rehanbahananrehan-spec/Pemegroman-Dasar/blob/main/Praktikum_(1)_Pemrograman_Dasar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya
nama = "Rehan"
nim  = "4232501051"
umur = "19"
asal = "kabanambas"
jurusan = "TRPE"
semester = 3
matakuliah = "Pemrograman Dasar"
status_lulus = False

print ("Nama : ", nama)
print ("NIM  : ", nim)
print ("Umur : ", umur)
print ("Asal : ", asal)
print ("Jurusan : ", jurusan)
print ("Semester : ", semester)
print ("Mata Kuliah : ", matakuliah)
print ("Status Lulus : ", status_lulus)
# Out:
# Nama :  Rehan
# NIM  :  4232501051
# Umur :  19
# Asal :  kabanambas
# Jurusan :  TRPE
# Semester :  3
# Mata Kuliah :  Pemrograman Dasar
# Status Lulus :  False
